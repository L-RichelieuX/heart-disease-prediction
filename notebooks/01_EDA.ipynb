# %% [markdown]
# # Exploratory Data Analysis — Heart Disease Dataset
#
# This notebook performs a comprehensive exploratory data analysis on the UCI Heart Disease dataset. We will:
#
# 1. Load and inspect the data
# 2. Examine the target variable distribution
# 3. Analyze numerical and categorical features
# 4. Visualize relationships between features and the target
# 5. Identify patterns and potential predictors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
plt.rcParams.update({
    "figure.dpi": 120,
    "font.size": 11,
    "axes.titlesize": 13,
})

import sys
sys.path.append("..")
from src.preprocess import load_data, inspect_data
